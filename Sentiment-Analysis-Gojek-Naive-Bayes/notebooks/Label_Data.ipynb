# %%
# !pip install pandas
# !pip install numpy
# !pip install nltk
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.23.5)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2023.6.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.1)

# %%
#untuk komputasi numerik
import numpy as pd

#memproses pengolahan text
import nltk

#membantu mempermudah manipulasi data teks
import string

#mencari pola kata spesifik yang dicari
import re

#hilangkan notif karena migrasi dari python
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # New Section

# %% [markdown]
# # New Section

# %%
#import Library yang dibutuhkan
import pandas as pd
from tqdm import tqdm, notebook
import warnings
warnings.filterwarnings('ignore')

pd.pandas.set_option('display.max_columns', None)
pd.pandas.set_option('display.max_rows', None)
pd.pandas.set_option('display.max_colwidth', None)
pd.pandas.set_option('display.width', None)

# %%
df = pd.read_csv('/content/DataSetGojek.csv')
df.head()
# Out:
#               userName  score                   at  \
# 0        Namanya Ayang      1  2023-11-08 10:38:23
# 1           Rezki Awan      2  2023-11-08 10:36:18
# 2          Bayu Langit      1  2023-11-08 10:32:41
# 3  Imong Fadhlurrahman      5  2023-11-08 10:32:12
# 4          Efi Juhaefi      1  2023-11-08 10:20:53
#
#                                                                                             content
# 0                                                                          Download lama banget loh
# 1                                                                     drivers food nya pada g jelas
# 2  Sistem gojek makin kesini makin kacau !!!! Kasian drivernya, aplikasi tanpa rasa kemanusiaan !!!
# 3                                                                                            akurat
# 4                           Mo transfer di suruh upgrade Giliran upgrade gagal mulu Ga jelas banget

# %%
df['sentiment'] = df['score'].map({1.0:0,2.0:0,3.0:1, 4.0:1, 5.0:1})

# %%
#Ambil teks aja untuk kita labelkan
dataku = pd.DataFrame(df[['content','sentiment']])
dataku.head(10)
# Out:
#                                                                                                                                                                                                                                                                                       content  \
# 0                                                                                                                                                                                                                                                                    Download lama banget loh
# 1                                                                                                                                                                                                                                                               drivers food nya pada g jelas
# 2                                                                                                                                                                                            Sistem gojek makin kesini makin kacau !!!! Kasian drivernya, aplikasi tanpa rasa kemanusiaan !!!
# 3                                                                                                                                                                                                                                                                                      akurat
# 4                                                                                                                                                                                                                     Mo transfer di suruh upgrade Giliran upgrade gagal mulu Ga jelas banget
# 5  Tolong perbaiki, setelah update bukan baik malah aneh-aneh, masa belum tekan untuk memesan, nih aplikasi malah mesan sendiri dan gojek yang datang malah dua akibat aplikasi lucu ini mesen sendiri, sekarang yang rugi siapa ? Aku kan, karna udah kepotong. TOLONG PERBAIKI KEMBALI !!!.
# 6                                                                                                                                                                                                                                                                                     ok baik
# 7                                                                                                                                                                                                                                                                                   Gojek Oke
# 8                                                                                                                                                                                                                                                                          Bagus sekali cepat
# 9                                                                                                                                                                                                                                                                            Tetap semangat ✊
#
#    sentiment
# 0          0
# 1          0
# 2          0
# 3          1
# 4          0
# 5          0
# 6          1
# 7          1
# 8          1
# 9          0
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['sentiment'].plot(kind='hist', bins=20, title='sentiment')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_1['sentiment'].plot(kind='line', figsize=(8, 4), title='sentiment')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
my_df = dataku[['content','sentiment']]

# %%
#simpan Dataset ke dalam File
my_df.to_csv("label_gojek.csv", index = False)
